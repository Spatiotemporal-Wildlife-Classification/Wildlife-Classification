# %%
import numpy as np
import pandas as pd

# %%
data_path = '../data/processed/'

df = pd.read_csv(data_path + 'final_test_observations.csv')

# %%
df.head()
# Out:
#       id observed_on     local_time_observed_at   latitude  longitude  \
# 0   4126  2009-07-25  2009-07-25 10:58:00+02:00 -19.502735  23.298196
# 1  16346  2007-11-29  2007-11-30 00:03:00+02:00 -20.253259  25.194044
# 2  17083  2007-11-26  2007-11-27 00:58:00+02:00 -19.595253  23.228511
# 3  17460  2010-04-03  2010-04-03 16:58:00+02:00 -19.271202  14.153619
# 4  56825  2011-07-22  2011-07-22 09:43:00+02:00 -18.752899  24.488977
#
#    positional_accuracy  public_positional_accuracy  \
# 0                  NaN                     30562.0
# 1                  NaN                     30490.0
# 2                  NaN                     30562.0
# 3                  NaN                     30580.0
# 4              62469.0                     62469.0
#
#                                            image_url      license geoprivacy  \
# 0  https://inaturalist-open-data.s3.amazonaws.com...  CC-BY-NC-ND        NaN
# 1  https://inaturalist-open-data.s3.amazonaws.com...        CC-BY        NaN
# ...

# %%
exp_df = df.groupby('taxon_species_name').apply(pd.DataFrame.sample, frac=0.025)

# %%
exp_df.shape
# Out:
# (130, 72)

# %%
exp_df = exp_df.reset_index(drop=True)

# %%
exp_df.head()
# Out:
#           id observed_on     local_time_observed_at   latitude  longitude  \
# 0  147524211  2022-07-02  2022-07-02 10:17:29+02:00 -32.113431  25.589933
# 1    4237765  2012-12-15  2012-12-16 05:46:12+03:00  -0.032427  37.969898
# 2   74653041  2021-01-16  2021-01-16 12:53:00+02:00 -28.274081  31.952610
# 3   75463466  2014-10-31  2014-10-31 17:01:00+02:00 -25.141028  31.844422
# 4   44156249  2020-04-25  2020-04-25 04:38:00+02:00 -33.586233  23.432841
#
#    positional_accuracy  public_positional_accuracy  \
# 0                196.0                     29146.0
# 1             716647.0                    716647.0
# 2               1953.0                     29631.0
# 3               3906.0                     30003.0
# 4                 61.0                        61.0
#
#                                            image_url      license geoprivacy  \
# 0  https://inaturalist-open-data.s3.amazonaws.com...     CC-BY-NC        NaN
# ...

# %%
exp_df.to_csv(data_path + 'ensemble_test.csv', index=False)
